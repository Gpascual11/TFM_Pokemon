# %%
from src.analysis_utils import load_and_clean, plot_comparison, get_statistics, create_tfm_boxplot
import pandas as pd
import importlib

# %%
df_random = load_and_clean("../data/tfm_results_10k_41ab.csv", "Heuristic vs Heuristic")
df_self = load_and_clean("../data/tfm_expert_results_5729.csv", "Heuristic vs Heuristic pro")

# %%
df_all = pd.concat([df_random, df_self])

# %%
stats_df = get_statistics(df_all)
print("--- TFM Battle Statistics ---")
display(stats_df)
# Out:
# --- TFM Battle Statistics ---
#                      run_type     mean       std  min  max  count  win_rate_%
# 0      Heuristic vs Heuristic  17.4998  5.755720    6  130  10000       48.68
# 1  Heuristic vs Heuristic pro  22.6171  7.628165    7  132  10000       51.34

# %%
plot_comparison(df_all)

# %%
create_tfm_boxplot(df_all)
# Out:
#  Boxplot saved successfully at: ../data/tfm_boxplot_comparison.png
# /home/gerardpf/TFM/src/analysis_utils.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_combined, x='run_type', y='turns', palette="Set2")
