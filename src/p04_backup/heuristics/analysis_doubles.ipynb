# %%
import analysis_double as analysis

# %%
doubles_v1_csv = '../data/tfm_doubles_expert_471c.csv'
doubles_v2_csv = '../data/tfm_doubles_expert_2019.csv'

# %%
results_table = analysis.compare_singles_doubles(singles_csv, doubles_csv)

# %%
print("--- TFM Strategic Comparison: Battle Efficiency ---")
display(results_table)
# Out:
# --- TFM Strategic Comparison: Battle Efficiency ---
#     Format  Mean Turns    SD  95% CI (Turns)  Win Rate (%)
# 0  Singles       17.51  5.82  [17.39, 17.62]         50.15
# 1  Doubles       17.42  5.94  [17.30, 17.53]         50.38

# %%
from IPython.display import Image
Image('data/comparison_distribution.png')
